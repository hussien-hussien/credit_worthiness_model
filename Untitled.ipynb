# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn

# %matplotlib inline

# %%
# Out:
#        member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count        0.0  128137.000000  128137.000000    128137.000000
# mean         NaN   16274.853477   16274.853477     16272.178996
# std          NaN   10281.469095   10281.469095     10280.628944
# min          NaN    1000.000000    1000.000000       975.000000
# 25%          NaN    8400.000000    8400.000000      8400.000000
# 50%          NaN   14000.000000   14000.000000     14000.000000
# 75%          NaN   22500.000000   22500.000000     22500.000000
# max          NaN   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc  desc            dti    delinq_2yrs  \
# count  128137.000000  1.281370e+05   0.0  127906.000000  128137.000000
# mean      470.899584  8.579579e+04   NaN      21.066334       0.236817
# std       289.981923  1.031547e+05   NaN      19.723450       0.757796
# min        30.640000  0.000000e+00   NaN       0.000000       0.000000
# ...

# %%
df_2019Q4['loan_status'].value_counts()
# Out:
# Current               122626
# Fully Paid              3539
# In Grace Period         1079
# Late (31-120 days)       509
# Late (16-30 days)        304
# Charged Off               80
# Name: loan_status, dtype: int64

# %%
df_2019Q3['loan_status'].value_counts()
# Out:
# Current               129855
# Fully Paid              8758
# In Grace Period         1531
# Late (31-120 days)      1520
# Charged Off              693
# Late (16-30 days)        495
# Default                   49
# Name: loan_status, dtype: int64

# %%
df_2019Q2['loan_status'].value_counts()
# Out:
# Current               111526
# Fully Paid             12958
# Charged Off             2360
# Late (31-120 days)      2058
# In Grace Period         1550
# Late (16-30 days)        480
# Default                   72
# Name: loan_status, dtype: int64

# %%
df_2019Q1['loan_status'].value_counts()
# Out:
# Current               91148
# Fully Paid            16863
# Charged Off            3870
# Late (31-120 days)     1850
# In Grace Period        1406
# Late (16-30 days)       362
# Default                  74
# Name: loan_status, dtype: int64

# %%
df_2019Q4.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
df_2019Q3.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
df_2019Q2.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
loan_data['loan_status'].value_counts()
# Out:
# Current               455155
# Fully Paid             42118
# Charged Off             7003
# Late (31-120 days)      5937
# In Grace Period         5566
# Late (16-30 days)       1641
# Default                  195
# Name: loan_status, dtype: int64

# %%
pd.set_option('display.max_colwidth', -1)

# %%
for i in loan_data.columns:
    print(i)
# Out:
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# ...

# %%
# Evaluate percentage of missing values
default_rows = loan_data[loan_data['loan_status'] == 'Default']
percentage_of_na = (loan_data.isna().sum()) / loan_data.shape[0]
percentage_of_na_defaults = default_rows.isna().sum() / default_rows.shape[0]

# Are the majority of the 'mostly missing' values just missing because we they are attributes of defaulted loans?
display(percentage_of_na_defaults[percentage_of_na_defaults > 0.75])
display(percentage_of_na[percentage_of_na > 0.75])

# There doesn't appear to be a large discrepancy in Nan values between loan status, so we will just delete rows where there is over 75% missing values, There should be 41 less columns
# Out:
# member_id                                     1.000000
# desc                                          1.000000
# mths_since_last_record                        0.851282
# annual_inc_joint                              0.835897
# dti_joint                                     0.835897
# verification_status_joint                     0.856410
# mths_since_recent_bc_dlq                      0.753846
# revol_bal_joint                               0.835897
# sec_app_fico_range_low                        0.835897
# sec_app_fico_range_high                       0.835897
# sec_app_earliest_cr_line                      0.835897
# sec_app_inq_last_6mths                        0.835897
# sec_app_mort_acc                              0.835897
# sec_app_open_acc                              0.835897
# sec_app_revol_util                            0.841026
# sec_app_open_act_il                           0.835897
# sec_app_num_rev_accts                         0.835897
# ...

# %%
loan_data.dropna(thresh=(loan_data.shape[0] * 0.75), axis = 1).shape
# Out:
# (517623, 107)

# %%
loan_data.shape
# Out:
# (0, 150)

# %%
loan_data
# Out:
# Empty DataFrame
# ...

# %%
# Out:
# member_id                                     True
# desc                                          True
# mths_since_last_delinq                        True
# mths_since_last_record                        True
# mths_since_last_major_derog                   True
# annual_inc_joint                              True
# dti_joint                                     True
# verification_status_joint                     True
# mths_since_recent_bc_dlq                      True
# mths_since_recent_revol_delinq                True
# revol_bal_joint                               True
# sec_app_fico_range_low                        True
# sec_app_fico_range_high                       True
# sec_app_earliest_cr_line                      True
# sec_app_inq_last_6mths                        True
# sec_app_mort_acc                              True
# sec_app_open_acc                              True
# sec_app_revol_util                            True
# ...
